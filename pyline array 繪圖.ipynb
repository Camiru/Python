# %%
# %pylab inline #匯入畫圖模組
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
randn(10)
# Out:
# array([ 1.6362081 ,  0.97214577, -1.63333867, -0.18641143,  1.59183445,
#        -0.30045064,  0.16149053, -0.03454002,  0.35745129,  1.12713164])

# %%
sin(1)
# Out:
# 0.8414709848078965

# %%
sin(randn(10))
# Out:
# array([ 0.67253845,  0.99636739,  0.81060988,  0.05022298, -0.00304745,
#         0.72682315, -0.21695819,  0.68290039, -0.771334  , -0.25136501])

# %%
plot(randn(10))

# %%
x = randn(10)

# %%
y = randn(10)

# %%
x
# Out:
# array([ 0.13398356, -0.88469182, -0.21731079, -0.55373395, -0.08868048,
#        -0.12218311, -0.11892738, -0.67674734, -0.38469086, -0.65991437])

# %%
y
# Out:
# array([-0.89357156,  1.55377831, -0.07286515, -0.132791  ,  0.23770988,
#        -1.78235806, -2.02046477,  0.11144504, -1.28581409, -0.52694846])

# %%
scatter(x,y)

# %%
x = linspace(0,10,100)  #從0到10 取100個點

# %%
x
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
# ...

# %%
plot (x ,sin(x))  #plot 為 plot(x,y)

# %%
plot(x,x**2 + 2*x -3)

# %%
plot(x, sin(x) +0.5*x)

# %%
arr = array([1,3,9,8,55,4,3,1,7,6])

# %%
arr[3] #找出index是3的 (第四個)
# Out:
# 8

# %%
arr[1:4] #找出1:4
# Out:
# array([3, 9, 8])

# %%
arr[:4] #找出前四個
# Out:
# array([1, 3, 9, 8])

# %%
arr[4:]
# Out:
# array([55,  4,  3,  1,  7,  6])

# %%
arr[:]
# Out:
# array([ 1,  3,  9,  8, 55,  4,  3,  1,  7,  6])

# %% [markdown]
# 兩層的(像個矩陣或表格)

# %%
a = array([[1,3,9],[2,4,8]]) #1,3,9 為第一列 , 2,4,8為第二列

# %%
a
# Out:
# array([[1, 3, 9],
#        [2, 4, 8]])

# %%
a[1,1] #第2列 第2行 index從0開始
# Out:
# 4

# %%
a[0]
# Out:
# array([1, 3, 9])

# %%
a[:,1]
# Out:
# array([3, 4])

# %%
arr = randn(20)

# %%
arr
# Out:
# array([ 0.1245279 ,  0.35783166,  0.12101516,  1.01593079,  0.37671247,
#        -1.30043771,  0.67788987, -0.52830101, -0.44014985,  2.15115846,
#         0.60659696, -0.40189853, -0.4515567 , -0.11269041, -1.01011186,
#        -1.76907255,  0.06782196, -0.91468815,  0.67699146,  0.02830437])

# %%
arr > 0 #取大於 0的判斷
# Out:
# array([ True,  True,  True,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#         True,  True], dtype=bool)

# %%
arr[arr > 0]  #取大於 0的數字
# Out:
# array([ 0.1245279 ,  0.35783166,  0.12101516,  1.01593079,  0.37671247,
#         0.67788987,  2.15115846,  0.60659696,  0.06782196,  0.67699146,
#         0.02830437])

# %%
x = randn(100)
y = randn(100)

# %%
scatter(x,y)

# %%
x> 0
# Out:
# array([False,  True, False,  True,  True, False,  True,  True, False,
#         True, False, False,  True, False, False, False,  True, False,
#        False, False,  True,  True,  True, False, False, False,  True,
#        False,  True,  True, False, False,  True, False,  True, False,
#        False, False, False,  True,  True, False,  True,  True, False,
#         True, False,  True, False,  True, False, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True, False,
#         True, False, False, False,  True, False,  True,  True,  True,
#         True, False,  True, False, False, False, False,  True, False,
#         True,  True, False, False, False,  True,  True,  True,  True,
#         True, False,  True, False,  True,  True, False,  True,  True,  True], dtype=bool)

# %%
x[x > 0]
# Out:
# array([ 1.91987025,  0.53203946,  0.95399906,  1.53642152,  0.74120687,
#         0.8282969 ,  1.49768569,  0.6370362 ,  1.25216018,  1.4056932 ,
#         0.37332078,  1.24149381,  0.59245444,  0.49713507,  0.07458541,
#         0.8291014 ,  0.29803946,  0.15818155,  0.89453805,  0.82523084,
#         0.68321486,  1.36935291,  0.41464597,  0.86642787,  0.71634147,
#         0.91569158,  1.6624891 ,  0.49333552,  1.34260526,  1.00851068,
#         0.44953056,  1.29292435,  0.92756698,  0.91107153,  0.79633193,
#         1.64887745,  1.47099488,  0.40602883,  0.33838667,  0.66047825,
#         0.45024156,  0.89686553,  0.06782208,  0.99944195,  1.0944654 ,
#         0.40715034,  0.59518026,  0.20250604,  1.1101296 ,  2.12870418,
#         0.01580887,  0.77366021,  0.62038267])

# %%
y[x>0] # x大於0的相對值找出來
# Out:
# array([-1.21011094,  0.04972149,  0.26869994,  1.27761508,  0.41329469,
#        -0.68004054, -0.31145129,  1.25623306,  0.78810997, -1.40280319,
#        -0.54257044,  0.34423223,  0.85164884, -0.83321901,  0.95746103,
#        -1.57011174,  0.37375232,  2.09230323,  0.03289395, -0.64750469,
#        -1.40437865, -0.61175794,  0.00920671, -1.12530923, -0.9491395 ,
#         0.82218099, -1.22713008,  1.97778804,  0.07311354,  0.49796983,
#         1.32524819,  0.80468465, -1.39970361, -0.40007485,  1.30401841,
#        -0.96676861, -0.34228493, -1.38386026, -0.42713319, -1.90017392,
#        -0.15374733,  0.41834478,  0.20882601, -2.26800467,  1.06185441,
#         0.13377235,  0.24013767,  0.7248638 , -1.23328147,  0.13102897,
#        -0.6428031 , -0.09589773,  1.42431596])

# %%
scatter (x[x > 0 ] , y[x >0] , c='red')

# %%
scatter (x[x > 0 ] , y[x >0] , c='red')
scatter(x[x<=0] ,y[x<=0] , c='blue')

# %% [markdown]
# array大整形

# %%
m = randn(100)

# %%
m.shape
# Out:
# (100,)

# %%
m.shape = (20,5)

# %%
m
# Out:
# array([[ 0.49037574,  1.23265464, -0.17664489,  0.15222302,  1.20283347],
#        [-0.74352621, -0.46018627, -0.01595388, -0.90449176, -0.95751862],
#        [ 0.42496426, -0.97330832, -1.92488207,  0.80775103, -0.06661173],
#        [-0.769733  ,  1.12463377, -1.53994473,  0.49652245, -0.24212981],
#        [-1.50767225,  0.73558516,  0.56967439,  0.87488285, -0.2967679 ],
#        [ 0.20208998,  0.36486268,  0.56560724,  0.60828397, -1.08059649],
#        [ 1.51794279, -0.14984667, -1.28445484,  0.13386562,  0.54247967],
#        [ 1.78677923,  1.46120528,  0.17436318, -0.37696599, -0.12460731],
#        [-0.11392247,  0.58082002,  0.46924688, -0.47386115, -0.71123738],
#        [ 0.9101176 , -0.26324433,  1.30179744, -1.41395054, -1.43247865],
#        [-0.12248801,  0.29444126,  1.3971204 , -1.01762472,  0.46585214],
#        [-0.97583408,  0.00764934,  1.41627521,  1.17216403,  0.55441586],
#        [ 0.3420872 ,  0.7942012 , -1.64347992, -0.9408966 ,  0.64799768],
# ...

# %%
m.shape = 100 #改變array 維度

# %%
m
# Out:
# array([ 0.49037574,  1.23265464, -0.17664489,  0.15222302,  1.20283347,
#        -0.74352621, -0.46018627, -0.01595388, -0.90449176, -0.95751862,
#         0.42496426, -0.97330832, -1.92488207,  0.80775103, -0.06661173,
#        -0.769733  ,  1.12463377, -1.53994473,  0.49652245, -0.24212981,
#        -1.50767225,  0.73558516,  0.56967439,  0.87488285, -0.2967679 ,
#         0.20208998,  0.36486268,  0.56560724,  0.60828397, -1.08059649,
#         1.51794279, -0.14984667, -1.28445484,  0.13386562,  0.54247967,
#         1.78677923,  1.46120528,  0.17436318, -0.37696599, -0.12460731,
#        -0.11392247,  0.58082002,  0.46924688, -0.47386115, -0.71123738,
#         0.9101176 , -0.26324433,  1.30179744, -1.41395054, -1.43247865,
#        -0.12248801,  0.29444126,  1.3971204 , -1.01762472,  0.46585214,
#        -0.97583408,  0.00764934,  1.41627521,  1.17216403,  0.55441586,
#         0.3420872 ,  0.7942012 , -1.64347992, -0.9408966 ,  0.64799768,
# ...

# %%
arr = randn(20,5)

# %%
arr
# Out:
# array([[ 0.4264611 , -1.37406569,  1.50023137,  0.88041136,  0.95222753],
#        [ 1.65785298,  2.53089222,  0.68281353, -1.08616499,  0.43007219],
#        [-1.71670767,  0.99203807, -1.12444256,  0.50298824, -1.79144386],
#        [ 0.20179681,  0.3639319 , -0.02596941, -1.67202663, -0.00723716],
#        [-0.74237769,  0.11257413,  0.120074  ,  0.14304761, -0.12516484],
#        [-1.00469521,  1.49834002, -0.50987208,  0.1040389 ,  2.79429495],
#        [ 2.38679526,  0.91520938,  0.41880451, -0.95696399, -1.16997135],
#        [-0.17403345, -1.61135464,  1.65002856,  0.89063851,  0.29598338],
#        [ 0.22076131, -0.18632828,  1.33940898, -0.77212038,  1.9262308 ],
#        [ 0.61130129,  0.36053845, -0.55264457,  0.05569626, -0.35524857],
#        [ 0.93410631,  0.19181247, -1.11251004, -2.15243324, -0.67621834],
#        [-0.42090397, -0.52103048, -0.31477985, -1.14002031,  1.00679231],
#        [ 0.07663536, -0.1199189 , -0.67731015, -0.00768918,  0.69382568],
# ...

# %%
I = eye(3)

# %%
I
# Out:
# array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
O = zeros(4)

# %%
O
# Out:
# array([ 0.,  0.,  0.,  0.])

# %%
O.shape = (2,2)

# %%
O
# Out:
# array([[ 0.,  0.],
#        [ 0.,  0.]])

# %%
lst = range(10)
arr = array(lst)

# %%
arr**2
# Out:
# array([ 0,  1,  4,  9, 16, 25, 36, 49, 64, 81])

# %%
randn(100)  #取 100 個亂數, 要符合常態分配, 以 0 為平均, 標準差是 1。
# Out:
# array([ 0.65523166, -0.13093407, -0.43361981, -0.12098471,  0.07420821,
#         0.43566818, -0.41618556, -1.5466795 ,  0.04491863, -0.26408729,
#        -0.30406981,  1.36003112,  1.58245757, -1.82239496, -0.23694505,
#         1.52470368, -0.31742598,  0.95240502, -1.23664456,  0.16061973,
#         1.29695309,  1.67094301, -0.37090898,  1.04063992, -0.14565919,
#         0.65168325,  0.47799718, -1.25540952,  0.74825175,  1.19289486,
#        -1.22808912, -0.70188537,  0.9466412 , -0.55407703,  0.12108553,
#         0.72568045, -0.28703924, -0.80301489, -1.52003745, -0.91377133,
#        -0.34014133,  1.64516709, -0.20459031,  0.37743849,  0.19468034,
#         0.95548592,  0.57108916, -0.10622081,  1.40118492,  1.86687196,
#        -0.89636393,  1.55060479, -0.51192135,  0.02832465, -1.29688452,
#         1.1473797 ,  1.4172932 , -0.1586264 ,  2.41210749, -1.12770269,
#         1.70503848,  0.58197412, -0.11935826, -1.35043893,  0.54159562,
# ...

# %%
x = linspace(0,5,100)

# %%
x
# Out:
# array([ 0.        ,  0.05050505,  0.1010101 ,  0.15151515,  0.2020202 ,
#         0.25252525,  0.3030303 ,  0.35353535,  0.4040404 ,  0.45454545,
#         0.50505051,  0.55555556,  0.60606061,  0.65656566,  0.70707071,
#         0.75757576,  0.80808081,  0.85858586,  0.90909091,  0.95959596,
#         1.01010101,  1.06060606,  1.11111111,  1.16161616,  1.21212121,
#         1.26262626,  1.31313131,  1.36363636,  1.41414141,  1.46464646,
#         1.51515152,  1.56565657,  1.61616162,  1.66666667,  1.71717172,
#         1.76767677,  1.81818182,  1.86868687,  1.91919192,  1.96969697,
#         2.02020202,  2.07070707,  2.12121212,  2.17171717,  2.22222222,
#         2.27272727,  2.32323232,  2.37373737,  2.42424242,  2.47474747,
#         2.52525253,  2.57575758,  2.62626263,  2.67676768,  2.72727273,
#         2.77777778,  2.82828283,  2.87878788,  2.92929293,  2.97979798,
#         3.03030303,  3.08080808,  3.13131313,  3.18181818,  3.23232323,
# ...

# %%
arr = normal (60, 10 ,55)

# %%
arr
# Out:
# array([ 62.25657436,  55.32792651,  53.19250638,  50.26760362,
#         56.29575155,  72.15897458,  56.20075789,  61.83817228,
#         70.69225457,  49.1959    ,  72.11833446,  62.91881918,
#         66.1033494 ,  45.25129756,  56.3303256 ,  56.76631788,
#         66.75629822,  67.41707125,  67.51512625,  68.8178684 ,
#         52.21498419,  37.37548121,  41.44349182,  65.69410009,
#         67.25382944,  58.80009674,  64.93290472,  50.85336575,
#         71.53343378,  72.74960877,  52.99723063,  39.13971186,
#         64.63451511,  52.36870161,  76.8504157 ,  30.73941493,
#         57.09525675,  51.17067885,  53.89971072,  56.09607083,
#         64.64831156,  75.69986453,  67.22244829,  45.57690006,
#         53.64722971,  74.91186828,  77.94486411,  53.74741901,
#         63.99872003,  52.92380231,  40.41698741,  48.00555992,
#         60.82875319,  60.03249439,  60.79787947])

# %%
arr.mean() #看全部同學平均成績
# Out:
# 58.830315195355432

# %%
arr>=60
# Out:
# array([ True, False, False, False, False,  True, False,  True,  True,
#        False,  True,  True,  True, False, False, False,  True,  True,
#         True,  True, False, False, False,  True,  True, False,  True,
#        False,  True,  True, False, False,  True, False,  True, False,
#        False, False, False, False,  True,  True,  True, False, False,
#         True,  True, False,  True, False, False, False,  True,  True,  True], dtype=bool)

# %%
arr[arr>=60] #只要看及格同學
# Out:
# array([ 62.25657436,  72.15897458,  61.83817228,  70.69225457,
#         72.11833446,  62.91881918,  66.1033494 ,  66.75629822,
#         67.41707125,  67.51512625,  68.8178684 ,  65.69410009,
#         67.25382944,  64.93290472,  71.53343378,  72.74960877,
#         64.63451511,  76.8504157 ,  64.64831156,  75.69986453,
#         67.22244829,  74.91186828,  77.94486411,  63.99872003,
#         60.82875319,  60.03249439,  60.79787947])

# %%
arr[arr>=60].mean() #看及格同學平均。
# Out:
# 67.715809423328409

# %%
lst = arr[arr<60]

# %%
lst
# Out:
# array([ 55.32792651,  53.19250638,  50.26760362,  56.29575155,
#         56.20075789,  49.1959    ,  45.25129756,  56.3303256 ,
#         56.76631788,  52.21498419,  37.37548121,  41.44349182,
#         58.80009674,  50.85336575,  52.99723063,  39.13971186,
#         52.36870161,  30.73941493,  57.09525675,  51.17067885,
#         53.89971072,  56.09607083,  45.57690006,  53.64722971,
#         53.74741901,  52.92380231,  40.41698741,  48.00555992])

# %%
len(lst)
# Out:
# 28

# %%
from IPython.html.widgets import interact

# %%
def f(x):
    print (x)

# %%
f(3)
# Out:
# 3

# %%
f('hi')
# Out:
# hi

# %%
interact(f,x=(1,10))
# Out:
# 5
# <function __main__.f>

# %%
interact (f , x=3);
# Out:
# 3

# %%
from IPython.html.widgets import interact_manual

# %%
interact (f , x=3);
# Out:
# 3

# %%
from ipywidgets import interact ,interact_manual

# %%
def f(x):
    print(x)

# %%
interact (f , x=3);
# Out:
# 3
